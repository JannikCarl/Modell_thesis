# %% [markdown]
# # Modell zur Bachelorarbeit

# %%
#from __future__ import print_function, division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from datetime import datetime
#import math
import dill # Transfer data for analysis
# Map in the background of the network plots relies on the mpl_toolkits and the basemap packages to be installed
from custom_thesis_functions import create_pickle_path

import pypsa

# %matplotlib inline

# %%
period = pd.date_range(start='2017-01-21 00:00', end='2017-01-28 23:45', freq='h')
pickle_loc = r"C:\Users\janni\OneDrive\TU Berlin\4 - Abschlussarbeiten\01 - Bachelorarbeit\validierung\\"

# %% [markdown]
# ## Import of the previously created network

# %%
with open(create_pickle_path('network', period, pickle_loc), "rb") as f:
    network = dill.load(f)

# %% [raw]
# with open("gen_names.pickle", 'rb') as f:
#     gen_names = dill.load(f)

# %% [raw]
# with open("network_demand.pickle", 'rb') as f:
#     network_demand = dill.load(f)

# %% [markdown]
# ## Visualization

# %% [markdown]
# ## Map topography

# %% [markdown]
# Map in the background relies on the mpl_toolkits and the basemap packages to be installed

# %%
fig,ax=plt.subplots(1,1)

network.plot(bus_sizes=20, title="Aufbau")
# Out:
# (<matplotlib.collections.PathCollection at 0x16a002d6b38>,
#  <matplotlib.collections.LineCollection at 0x16a0887e128>)

# %%
gen_outs = network.generators_t.p / 1000
# No negative values for plotting
gen_outs[gen_outs < 0] = 0

# %%
gen_outs = gen_outs.applymap(lambda item: 0 if not(np.isreal(item)) else item)

# %%
power_by_carrier = gen_outs.groupby(network.generators.carrier, axis=1).sum()

# %%
network.generators.carrier.head(2)
# Out:
# Import Dänemark       Import
# Import Niederlande    Import
# Name: carrier, dtype: object

# %%
power_by_carrier.head(2)
# Out:
# carrier              Import   Wind      ee
# 2017-01-21 00:00:00     0.0  0.300  10.154
# 2017-01-21 01:00:00     0.0  0.248   9.967

# %%
graph_colors = {"Erdgas":"orange",
                "Braunkohle":"brown",
                "Steinkohle":"black",
                "Wind":"blue",
                "ee":"green",
                "Import":"red"}

col_order = ["Wind", "ee", "Braunkohle", "Steinkohle", "Erdgas", "Import"]
# power_by_carrier = power_by_carrier[col_order]

# %%
network.objective
# Out:
# 107771306.119

# %% [raw]
# fig,ax = plt.subplots(1,1)
# fig.set_size_inches(30,10)
#
# (gen_outs).plot(kind="area",ax=ax, grid=True)
#
# ax.set_xlabel("Snaps")
# ax.set_ylabel("MW")

# %%
fig,ax = plt.subplots(1,1)
fig.set_size_inches(30,10)

power_by_carrier.plot(kind="area",ax=ax, grid=True, color=[graph_colors[i] for i in power_by_carrier.columns])

ax.set_xlabel("Snaps")
ax.set_ylabel("MW")
# Out:
# Text(0,0.5,'MW')

# %%
fig,ax=plt.subplots(nrows=1, ncols=1, figsize=(6,6))

perc_load = network.lines_t.p0.iloc[45] / network.lines.s_nom

dist = network.plot(bus_sizes=30, line_colors=abs(perc_load), title="Leitungsauslastung", line_cmap="YlOrBr")

# %%
fig, ax = plt.subplots()

rel_bus_size = (network_demand.mean().values.tolist() / network_demand.mean().values.sum())*400

# set buses abroad to basic size
i = len(network.buses) - len(rel_bus_size)
while i <= len(network.buses):
    rel_bus_size = np.append(rel_bus_size, 20)
    i += 1

ax = network.plot(bus_sizes=rel_bus_size*2, title="Lastverteilung")
